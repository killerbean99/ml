# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from tqdm import tqdm

import librosa
from librosa import display as dp
from scipy.io import wavfile

# %%
root = '../../VALERIO/FreeSpokenDigit/recordings/'
files = os.listdir(root)

# %%
print(f'{len(files)} FILES IN FOLDER')
# Out:
# 3000 FILES IN FOLDER

# %%
def extract_spectrogram(y, sr=8000, n_fft=None) -> np.array:
    '''
    y = time series audio
    sr = sample rate (8000 by default)
    
    returns: np.array of spectrogram
    '''
    if n_fft:
        stft = librosa.stft(y, n_fft=n_fft)
    else:
        stft = librosa.stft(y)
    spectrogram = np.abs(stft)**2
    return spectrogram

def extract_melspectrogram(y, sr=8000, n_fft=2048, hop_length=512, win_length=None) -> np.array:
    '''
    y = time series audio
    sr = sample rate (8000 by default)
    TODO: define other parameters
    
    returns: np.array of melspectrogram
    '''
    melspectrogram = librosa.feature.melspectrogram(y, sr=sr)
    return melspectrogram

def extract_mfcc(y, sr=8000, n_mfcc=20):
    '''
    y = time series audio
    sr = sample rate (8000 by default)
    n_mfcc = numner of MFCC
    
    returns: np.array of mfcc
    '''
    mfcc = librosa.feature.mfcc(y=y, sr=sr)
    return mfcc

# %%
def cut_if_necessary(y=y, size=8000):
    '''
    cuts audios with duration over size
    y = time series audio
    size = duration of audio that we need (i.g. if sr=8000Hz then 1sec=8000, 0.5=4000)
    returns: np.array of y
    '''
    if y.shape[0] > size:
        y = y[:size]

    return y

def pad_if_necessary(y=y, size=8000):
    '''
    pads audios with duration less than size with zeros
    y = time series audio
    size = duration of audio that we need (i.g. if sr=8000Hz then 1sec=8000, 0.5=4000)
    returns: np.array of y
    '''
    if y.shape[0] < size:
        diff = size - y.shape[0]
        zeros = np.zeros((diff))
        y = np.concatenate([y, zeros])

    return y

# %%
def save_numpy(root_path, fname, arr):
    dst_path = os.path.join(root_path, fname)
    np.save(dst_path, arr)

# %%
dst = 'features'
dst_spec = 'spectrograms'
dst_melspecs = 'melspectrograms'
dst_mfcc = 'mfcc'

# %%
os.makedirs(dst, exist_ok=True)
os.makedirs(os.path.join(dst, dst_melspecs), exist_ok=True)
os.makedirs(os.path.join(dst, dst_mfcc), exist_ok=True)
os.makedirs(os.path.join(dst, dst_spec), exist_ok=True)

# %%
for f in tqdm(files):
    fpath = os.path.join(root, f)
    fname = os.path.splitext(f)[0]
    
    y, sr = librosa.load(fpath, sr=None)
    
    y = cut_if_necessary(y)
    
    spec = extract_spectrogram(y)
    melpec = extract_melspectrogram(y)
    mfcc = extract_mfcc(y)
    
    save_numpy(os.path.join(dst, dst_spec), fname=fname, arr=spec)
    save_numpy(os.path.join(dst, dst_melspecs), fname=fname, arr=melpec)
    save_numpy(os.path.join(dst, dst_mfcc), fname=fname, arr=mfcc)
# Out:
#   0%|          | 0/3000 [00:00<?, ?it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1807
#   warnings.warn(
#   0%|          | 15/3000 [00:00<00:21, 140.40it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1970
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1713
#   warnings.warn(
#   1%|          | 30/3000 [00:00<00:21, 139.42it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1968
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1866
#   warnings.warn(
#   1%|▏         | 44/3000 [00:00<00:22, 132.63it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=2016
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1434
#   warnings.warn(
#   2%|▏         | 58/3000 [00:00<00:22, 131.89it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1886
#   warnings.warn(
#   2%|▏         | 72/3000 [00:00<00:22, 132.91it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1650
#   warnings.warn(
#   3%|▎         | 87/3000 [00:00<00:21, 135.89it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1801
#   warnings.warn(
#   3%|▎         | 101/3000 [00:00<00:21, 133.23it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=2015
#   warnings.warn(
#   4%|▍         | 116/3000 [00:00<00:21, 136.01it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1357
#   warnings.warn(
#   4%|▍         | 130/3000 [00:00<00:21, 134.65it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1493
#   warnings.warn(
#   5%|▍         | 145/3000 [00:01<00:20, 137.99it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1868
#   warnings.warn(
#   5%|▌         | 161/3000 [00:01<00:19, 142.54it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=2039
#   warnings.warn(
#   7%|▋         | 204/3000 [00:01<00:20, 135.74it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1259
#   warnings.warn(
#   7%|▋         | 218/3000 [00:01<00:21, 128.85it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1963
#   warnings.warn(
#   8%|▊         | 232/3000 [00:01<00:21, 129.13it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=2007
#   warnings.warn(
#   9%|▊         | 262/3000 [00:01<00:19, 137.47it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1962
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1933
#   warnings.warn(
#  10%|█         | 307/3000 [00:02<00:19, 138.87it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1896
#   warnings.warn(
#  12%|█▏        | 352/3000 [00:02<00:18, 142.99it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1858
#   warnings.warn(
#  12%|█▏        | 367/3000 [00:02<00:18, 144.07it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1785
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1410
#   warnings.warn(
#  13%|█▎        | 382/3000 [00:02<00:18, 141.08it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1778
#   warnings.warn(
#  14%|█▍        | 427/3000 [00:03<00:18, 138.89it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1987
#   warnings.warn(
#  15%|█▌        | 458/3000 [00:03<00:17, 143.57it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1296
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1712
#   warnings.warn(
#  16%|█▌        | 473/3000 [00:03<00:18, 139.68it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1601
#   warnings.warn(
#  16%|█▋        | 488/3000 [00:03<00:17, 141.64it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=2042
#   warnings.warn(
#  17%|█▋        | 503/3000 [00:03<00:17, 139.71it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1579
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1795
#   warnings.warn(
#  17%|█▋        | 517/3000 [00:03<00:18, 136.10it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1597
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1565
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1774
#   warnings.warn(
#  18%|█▊        | 531/3000 [00:03<00:18, 135.60it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1542
#   warnings.warn(
#  18%|█▊        | 545/3000 [00:03<00:18, 129.21it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1627
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1502
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1568
#   warnings.warn(
#  19%|█▊        | 560/3000 [00:04<00:18, 133.66it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1824
#   warnings.warn(
#  19%|█▉        | 575/3000 [00:04<00:17, 138.03it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=2035
#   warnings.warn(
#  20%|██        | 603/3000 [00:04<00:17, 138.34it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1852
#   warnings.warn(
#  21%|██        | 619/3000 [00:04<00:16, 142.46it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1403
#   warnings.warn(
#  21%|██        | 635/3000 [00:04<00:16, 145.70it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1806
#   warnings.warn(
#  22%|██▏       | 650/3000 [00:04<00:17, 137.73it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1850
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1664
#   warnings.warn(
#  22%|██▏       | 665/3000 [00:04<00:16, 140.48it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1891
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1876
#   warnings.warn(
#  23%|██▎       | 694/3000 [00:05<00:17, 133.57it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1567
#   warnings.warn(
#  24%|██▎       | 708/3000 [00:05<00:17, 134.54it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1302
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1843
#   warnings.warn(
#  24%|██▍       | 722/3000 [00:05<00:17, 130.50it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1705
#   warnings.warn(
#  25%|██▍       | 737/3000 [00:05<00:16, 135.72it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1433
#   warnings.warn(
#  25%|██▌       | 751/3000 [00:05<00:16, 136.32it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1838
#   warnings.warn(
#  26%|██▌       | 765/3000 [00:05<00:16, 131.84it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1381
#   warnings.warn(
#  26%|██▋       | 794/3000 [00:05<00:16, 131.83it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1976
#   warnings.warn(
#  27%|██▋       | 808/3000 [00:05<00:17, 124.60it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1995
#   warnings.warn(
#  27%|██▋       | 823/3000 [00:06<00:16, 130.22it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1965
#   warnings.warn(
#  30%|██▉       | 896/3000 [00:06<00:14, 140.54it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=2020
#   warnings.warn(
#  31%|███       | 926/3000 [00:06<00:14, 140.57it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1538
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1960
#   warnings.warn(
#  32%|███▏      | 956/3000 [00:06<00:14, 141.73it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1556
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=2001
#   warnings.warn(
#  32%|███▏      | 971/3000 [00:07<00:14, 140.39it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1710
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1634
#   warnings.warn(
#  33%|███▎      | 1003/3000 [00:07<00:13, 147.76it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1919
#   warnings.warn(
#  34%|███▍      | 1018/3000 [00:07<00:13, 147.79it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=2005
#   warnings.warn(
#  35%|███▍      | 1049/3000 [00:07<00:13, 148.13it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1788
#   warnings.warn(
#  36%|███▌      | 1065/3000 [00:07<00:12, 149.41it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1359
#   warnings.warn(
#  36%|███▌      | 1080/3000 [00:07<00:12, 148.55it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=2036
#   warnings.warn(
#  37%|███▋      | 1112/3000 [00:08<00:12, 150.04it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=2023
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=2034
#   warnings.warn(
#  38%|███▊      | 1128/3000 [00:08<00:12, 149.24it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1749
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1560
#   warnings.warn(
#  38%|███▊      | 1143/3000 [00:08<00:12, 149.42it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1790
#   warnings.warn(
#  39%|███▉      | 1173/3000 [00:08<00:12, 148.16it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1714
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1837
#   warnings.warn(
#  40%|███▉      | 1188/3000 [00:08<00:12, 147.30it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1870
#   warnings.warn(
#  41%|████      | 1219/3000 [00:08<00:12, 148.06it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1639
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1945
#   warnings.warn(
#  42%|████▏     | 1249/3000 [00:08<00:12, 143.87it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1873
#   warnings.warn(
#  42%|████▏     | 1265/3000 [00:09<00:11, 145.75it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1914
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1475
#   warnings.warn(
#  43%|████▎     | 1280/3000 [00:09<00:11, 144.13it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=2014
#   warnings.warn(
#  43%|████▎     | 1295/3000 [00:09<00:11, 143.82it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1761
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1803
#   warnings.warn(
#  44%|████▍     | 1326/3000 [00:09<00:11, 147.54it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1593
#   warnings.warn(
#  46%|████▌     | 1373/3000 [00:09<00:10, 149.40it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1525
#   warnings.warn(
#  46%|████▋     | 1389/3000 [00:09<00:10, 151.18it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=2022
#   warnings.warn(
#  47%|████▋     | 1405/3000 [00:10<00:10, 151.94it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1763
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=2043
#   warnings.warn(
#  48%|████▊     | 1453/3000 [00:10<00:10, 146.37it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1640
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1819
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1610
#   warnings.warn(
#  49%|████▉     | 1468/3000 [00:10<00:11, 137.20it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1742
#   warnings.warn(
#  49%|████▉     | 1484/3000 [00:10<00:10, 142.94it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1673
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1720
#   warnings.warn(
#  50%|█████     | 1514/3000 [00:10<00:10, 138.29it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1842
#   warnings.warn(
#  51%|█████     | 1530/3000 [00:10<00:10, 142.22it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1890
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=2027
#   warnings.warn(
#  53%|█████▎    | 1578/3000 [00:11<00:09, 149.88it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1399
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1805
#   warnings.warn(
#  54%|█████▎    | 1609/3000 [00:11<00:09, 143.47it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1737
#   warnings.warn(
#  55%|█████▍    | 1640/3000 [00:11<00:09, 148.87it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1903
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=2045
#   warnings.warn(
#  55%|█████▌    | 1655/3000 [00:11<00:09, 148.84it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1294
#   warnings.warn(
#  56%|█████▌    | 1671/3000 [00:11<00:08, 147.81it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1569
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1983
#   warnings.warn(
#  57%|█████▋    | 1701/3000 [00:12<00:09, 144.26it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1722
#   warnings.warn(
#  57%|█████▋    | 1716/3000 [00:12<00:09, 137.35it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1531
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1450
#   warnings.warn(
#  58%|█████▊    | 1731/3000 [00:12<00:09, 139.58it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1443
#   warnings.warn(
#  58%|█████▊    | 1746/3000 [00:12<00:09, 136.03it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1149
#   warnings.warn(
#  59%|█████▊    | 1761/3000 [00:12<00:09, 137.50it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1988
#   warnings.warn(
#  60%|██████    | 1805/3000 [00:12<00:08, 141.49it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=2044
#   warnings.warn(
#  61%|██████    | 1820/3000 [00:12<00:08, 137.08it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1813
#   warnings.warn(
#  61%|██████    | 1834/3000 [00:13<00:08, 137.05it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1833
#   warnings.warn(
#  62%|██████▏   | 1862/3000 [00:13<00:08, 131.89it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1148
#   warnings.warn(
#  63%|██████▎   | 1877/3000 [00:13<00:08, 133.31it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1516
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1906
#   warnings.warn(
#  63%|██████▎   | 1891/3000 [00:13<00:08, 132.80it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1832
#   warnings.warn(
#  64%|██████▍   | 1935/3000 [00:13<00:07, 138.99it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1781
#   warnings.warn(
#  65%|██████▌   | 1964/3000 [00:13<00:07, 138.14it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1288
#   warnings.warn(
#  66%|██████▌   | 1979/3000 [00:14<00:07, 141.10it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1880
#   warnings.warn(
#  68%|██████▊   | 2025/3000 [00:14<00:06, 142.39it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1440
#   warnings.warn(
#  68%|██████▊   | 2054/3000 [00:14<00:07, 129.63it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1932
#   warnings.warn(
#  69%|██████▉   | 2068/3000 [00:14<00:07, 125.68it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1953
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1455
#   warnings.warn(
#  70%|██████▉   | 2096/3000 [00:14<00:06, 131.28it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1682
#   warnings.warn(
#  71%|███████   | 2125/3000 [00:15<00:06, 131.88it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1753
#   warnings.warn(
#  71%|███████▏  | 2140/3000 [00:15<00:06, 135.90it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1251
#   warnings.warn(
#  72%|███████▏  | 2154/3000 [00:15<00:06, 135.65it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1817
#   warnings.warn(
#  73%|███████▎  | 2198/3000 [00:15<00:05, 138.51it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1704
#   warnings.warn(
#  75%|███████▌  | 2258/3000 [00:16<00:05, 139.95it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1697
#   warnings.warn(
#  76%|███████▋  | 2288/3000 [00:16<00:05, 139.94it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=2012
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1854
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1931
#   warnings.warn(
#  77%|███████▋  | 2318/3000 [00:16<00:04, 139.58it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1692
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1547
#   warnings.warn(
#  78%|███████▊  | 2347/3000 [00:16<00:04, 137.76it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1958
#   warnings.warn(
#  80%|████████  | 2406/3000 [00:17<00:04, 134.62it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1446
#   warnings.warn(
#  81%|████████  | 2421/3000 [00:17<00:04, 136.40it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1998
#   warnings.warn(
#  82%|████████▏ | 2450/3000 [00:17<00:04, 137.06it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1295
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1973
#   warnings.warn(
#  82%|████████▏ | 2465/3000 [00:17<00:03, 138.69it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1541
#   warnings.warn(
#  84%|████████▎ | 2509/3000 [00:17<00:03, 142.21it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1936
#   warnings.warn(
#  84%|████████▍ | 2524/3000 [00:18<00:03, 141.07it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1915
#   warnings.warn(
#  85%|████████▌ | 2555/3000 [00:18<00:03, 141.62it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1772
#   warnings.warn(
#  86%|████████▌ | 2570/3000 [00:18<00:03, 142.28it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1884
#   warnings.warn(
#  86%|████████▌ | 2585/3000 [00:18<00:02, 140.82it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1830
#   warnings.warn(
#  88%|████████▊ | 2630/3000 [00:18<00:02, 141.04it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1760
#   warnings.warn(
#  88%|████████▊ | 2645/3000 [00:18<00:02, 142.21it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1943
#   warnings.warn(
#  89%|████████▊ | 2660/3000 [00:19<00:02, 135.63it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1609
#   warnings.warn(
#  89%|████████▉ | 2674/3000 [00:19<00:02, 135.88it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1900
#   warnings.warn(
#  90%|████████▉ | 2689/3000 [00:19<00:02, 138.68it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=2037
#   warnings.warn(
#  90%|█████████ | 2703/3000 [00:19<00:02, 138.23it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1910
#   warnings.warn(
#  91%|█████████ | 2732/3000 [00:19<00:01, 139.19it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1632
#   warnings.warn(
#  92%|█████████▏| 2747/3000 [00:19<00:01, 140.00it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1913
#   warnings.warn(
#  92%|█████████▏| 2762/3000 [00:19<00:01, 137.97it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=2033
#   warnings.warn(
#  93%|█████████▎| 2792/3000 [00:19<00:01, 141.83it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1997
#   warnings.warn(
# /home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1892
#   warnings.warn(
#  96%|█████████▌| 2867/3000 [00:20<00:00, 144.31it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1846
#   warnings.warn(
#  97%|█████████▋| 2897/3000 [00:20<00:00, 143.81it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1793
#   warnings.warn(
#  98%|█████████▊| 2927/3000 [00:20<00:00, 145.22it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1978
#   warnings.warn(
#  98%|█████████▊| 2943/3000 [00:21<00:00, 146.25it/s]/home/aidos/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1911
#   warnings.warn(
# 100%|██████████| 3000/3000 [00:21<00:00, 139.93it/s]
