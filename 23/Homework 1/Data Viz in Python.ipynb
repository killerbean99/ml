# %% [markdown]
# # Data Visualization

# %%
import librosa
from scipy.io import wavfile
import matplotlib.pyplot as plt

# %%
wav_path = '0_george_0.wav'

# %%
with open(wav_path, 'rb') as handle:
    wav_bytes = handle.read()

# %%
wav_bytes
# Out:
# b'RIFF\xc4\x12\x00\x00WAVEfmt \x10\x00\x00\x00\x01\x00\x01\x00@\x1f\x00\x00\x80>\x00\x00\x02\x00\x10\x00data\xa0\x12\x00\x00/\xfa>\xfc\xa2\xfd\xa3\x00\t\x04\x85\x06Q\x08x\nK\x0c\xeb\x0c\xb9\x0c\xf6\x0c\xe2\x0b-\n\x93\x07;\x06\xd1\x04.\x02\x9f\xff\xe9\xfdY\xfe\\\xfc;\xfa\x99\xf9\xb3\xfc\xa8\xfd\x87\xf6.\xf9\x87\xfb\n\xf94\xf9\xeb\xf2\xf2\xf6\x10\xf9E\xf5\xd7\xf3\x1c\xf7 \xfc~\xf8)\xfdW\xfet\x02\xe8\x06\xc4\x03\x1f\nx\x0c\x02\r\x03\x0c7\r\x00\x0e\xe4\nF\x0b\xf3\x05!\x07\xb0\x051\xff\x9b\x00M\xffQ\xfdw\xfb\x8b\xfb\xf8\xfc}\xfdC\xfc\xf3\xfb \x01z\xff\x06\xfd\x90\xfdL\x00\xc6\x00|\xf9Q\xfck\xfb\xfe\xf8S\xf7\x97\xf1\n\xf6 \xf6o\xf2\xcb\xf2\xf1\xf7\x85\xfb\xde\xfba\xfe8\x02=\n\xe1\n\x1b\n\x17\x0f\n\x12\xdf\x11\x92\x0e0\x0e\n\x0fI\x0cJ\x06^\x02\x02\x04\x0b\x00\xca\xf9\x04\xf8\x01\xfa\xc2\xf9\xfd\xf4\x15\xf6\x1f\xf9\xec\xfa\xa4\xfa\'\xfb\xfd\xff\x10\x05\xc4\x02P\x00\xe7\x06\xb4\n\xd5\x06&\xff\'\xff\x0f\x02\x10\xfcC\xf2\xbe\xee\x9f\xf4\xf7\xf1\x08\xe9\xb3\xea\x9e\xf2*\xf8h\xf5\xb5\xf9\xa4\x089
# ...

# %%
amplitudes, sample_rate = librosa.load(wav_path, sr=None)

# %%
plt.plot(amplitudes[000:2500])

# %%
wf = wavfile.read(wav_path)

# %%
wf
# Out:
# (8000, array([-1489,  -962,  -606, ..., -1814, -1110,   -15], dtype=int16))
